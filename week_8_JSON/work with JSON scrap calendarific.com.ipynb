# %%
import json
import requests
import psycopg2
import pandas as pd
import os

# %% [markdown]
# ### add data to .bashrc- file
# in command window in root /home/kasia open **nano .bashrc**
# after that add write export XXXX=password f.exp. **DATABASE_NAME=string**
#
# in python we **import os** and use **os.environ.get('DATABASE_NAME')** to get the data

# %% [markdown]
# # Homework
# The practical exercise you can get started on and that we will review during the session next Monday:
#     - Sign up to use this api:
# https://calendarific.com/api-documentation
#     - Get the attached json file with a list of countries and store it into your Jupyter folder
# From Jupyter:
#     -  load the list of countries from the json and for each country
# get all holidays for year 2021 using the api
#     - Output the holidays to a local json file or Postgres table, with following attributes for each holiday:
#     country_name
#     holiday_name
#     holiday_date
#     type_observance

# %%
# fitler out only country code and request informations for holiday
def collect_data_for_countries(countries_codes:list,year:int)->list:
    """ open json-file with countries codes
        download data for countries in json-file from calendarific API and append to list"""

    API_URL = 'https://calendarific.com/api/v2/holidays?&api_key={}&country={}&year={}'    
    holiday_responses = []
    token = os.environ.get('TOKEN_CALENDARIFIC')
    countries_codes = list(set([c['code'] for c in countries_codes]))
    for code in countries_codes: 
        response = requests.get(API_URL.format(token,code,year))
        holiday_responses.append(json.loads(response.text))
    return holiday_responses
          


def select_holiday_info(holiday_responses:list)-> dict:  
    """  
        select data from list of dict
        append dict info for every holiday to list
        take country name for last record in response
        collect data to dict
        dict FORMAT example
        {'Tunisia': 
                [{'holiday_name': 'New Year','holiday_date': '2021-01-01','type_observance': 'National holiday'},
                  {'holiday_name': 'Revolution and Youth Day','holiday_date': '2021-01-14','type_observance': 'National holiday'}
                ]
        }
        """

    holiday_in_country = {}
    for response in holiday_responses:
        holiday_list = []
        for holiday_info in response['response']['holidays']:
            info = {
                'holiday_name': holiday_info['name'],
                'holiday_date':holiday_info['date']['iso'],
                'type_observance':holiday_info['type'][0]
                }
            holiday_list.append(info)
        holiday_in_country[holiday_info['country']['name']] = holiday_list
    return holiday_in_country 
#holiday = json.dumps(holiday_in_country,indent=3)
#print(holiday)

#### add to table

def prepare_holiday_info_for_df(holiday_responses:dict)->list:
    """ 
        prepare list of tuples which will be added to postgres table
    """


    country_list = []
    hol_info = []
    for country in  holiday_responses:
        country_list.append((country,))
        for hol in holiday_responses[country]:
            hol_info.append((country,hol['holiday_name'],hol['holiday_date'],hol['type_observance']))
    return hol_info,country_list

def insert_holiday_info_to_table(postgres_insert_query:str,hol_info):
    """insert data to table which is choose in query"""
    cur.executemany(postgres_insert_query, hol_info)
    conn.commit()

def create_pandas_table(sql_query, database = conn):
    table = pd.read_sql_query(sql_query, database)
    return table

# %%
#with open('country_list.json','r') as country_file:
    #countries_codes = json.load(country_file)


#holiday_responses = collect_data_for_countries(countries_codes,2021) 

#with open('country_holiday.json','w') as country_holiday_file:
    #json.dump(holiday_responses,country_holiday_file)
    
with open('country_holiday.json','r') as country_holiday_file:
    holiday_responses = json.load(country_holiday_file)
    
holiday_in_country = select_holiday_info(holiday_responses)

#with open('selected_holiday_info.json','w') as country_holiday_file:
    #json.dump(holiday_in_country,country_holiday_file)
holiday = json.dumps(holiday_in_country,indent=2)
print(holiday)
# Out:
# {
#   "Tunisia": [
#     {
#       "holiday_name": "New Year",
#       "holiday_date": "2021-01-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "
25",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Prophet's Ascension",
#       "holiday_date": "2021-03-11",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "March Equinox",
#       "holiday_date": "2021-03-20T13:07:30+03:30",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Norooz (Persian New Year)",
#       "holiday_date": "2021-03-21",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Norooz Holiday",
#       "holiday_date": "2021-03-22",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Norooz Holiday",
#       "holiday_date": "2021-03-23",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Norooz Holiday",
#       "holiday_date": "2021-03-24",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Imam Mahdi's birthday",
#       "holiday_date": "2021-03-29",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Martyrdom of Imam Ali",
#       "holiday_date": "2021-05-03",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Eid-e-Fetr (End of Ramadan)",
#       "holiday_date": "2021-05-13",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Eid-e-Fetr (Additional Holiday)",
#       "holiday_date": "2021-05-14",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Martyrdom of Imam Sadeq",
#       "holiday_date": "2021-06-06",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "June Solstice",
#       "holiday_date": "2021-06-21T08:02:08+04:30",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Eid-e-Ghorban (Feast of Sacrifice)",
#       "holiday_date": "2021-07-20",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Eid-e-Ghadir",
#       "holiday_date": "2021-07-28",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Tassoua",
#       "holiday_date": "2021-08-18",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Ashura",
#       "holiday_date": "2021-08-19",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "September Equinox",
#       "holiday_date": "2021-09-22T22:51:10+03:30",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Arbaeen",
#       "holiday_date": "2021-09-28",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Demise of Prophet Muhammad and Martyrdom of Imam Hassan",
#       "holiday_date": "2021-10-06",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Martyrdom of Imam Reza",
#       "holiday_date": "2021-10-07",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Martyrdom of Imam Hasan al-Askari",
#       "holiday_date": "2021-10-15",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Birthday of Prophet Muhammad and Imam Sadeq",
#       "holiday_date": "2021-10-24",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "December Solstice",
#       "holiday_date": "2021-12-21T19:29:17+03:30",
#       "type_observance": "Season"
#     }
#   ],
#   "Cote d'Ivoire": [
#     {
#       "holiday_name": "New Year",
#       "holiday_date": "2021-01-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "March Equinox",
#       "holiday_date": "2021-03-20T09:37:30+00:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Easter Monday",
#       "holiday_date": "2021-04-05",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Labor Day",
#       "holiday_date": "2021-05-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Day After Laila tou-Kadr",
#       "holiday_date": "2021-05-09",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Ascension Day",
#       "holiday_date": "2021-05-13",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Aid el-Fitr",
#       "holiday_date": "2021-05-13",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Whit Monday",
#       "holiday_date": "2021-05-24",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "June Solstice",
#       "holiday_date": "2021-06-21T03:32:08+00:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Aid el-Kebir",
#       "holiday_date": "2021-07-20",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Independence Day",
#       "holiday_date": "2021-08-07",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Assumption of Mary",
#       "holiday_date": "2021-08-15",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "September Equinox",
#       "holiday_date": "2021-09-22T19:21:10+00:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "The Day After Prophet's Birthday",
#       "holiday_date": "2021-10-20",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "All Saints Day",
#       "holiday_date": "2021-11-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "National Peace Day",
#       "holiday_date": "2021-11-15",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "December Solstice",
#       "holiday_date": "2021-12-21T15:59:17+00:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Christmas Day",
#       "holiday_date": "2021-12-25",
#       "type_observance": "National holiday"
#     }
#   ],
#   "Equatorial Guinea": [
#     {
#       "holiday_name": "New Year's Day",
#       "holiday_date": "2021-01-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "March Equinox",
#       "holiday_date": "2021-03-20T10:37:30+01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Maundy Thursday",
#       "holiday_date": "2021-04-01",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Good Friday",
#       "holiday_date": "2021-04-02",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Labor Day / May Day",
#       "holiday_date": "2021-05-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Corpus Christi",
#       "holiday_date": "2021-06-03",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "President's Day",
#       "holiday_date": "2021-06-05",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "June Solstice",
#       "holiday_date": "2021-06-21T04:32:08+01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Freedom Day",
#       "holiday_date": "2021-08-03",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Constitution Day",
#       "holiday_date": "2021-08-15",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Constitution Day observed",
#       "holiday_date": "2021-08-16",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "September Equinox",
#       "holiday_date": "2021-09-22T20:21:10+01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Independence Day",
#       "holiday_date": "2021-10-12",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Feast of the Immaculate Conception",
#       "holiday_date": "2021-12-08",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Human Rights Day",
#       "holiday_date": "2021-12-10",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "December Solstice",
#       "holiday_date": "2021-12-21T16:59:17+01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Christmas Eve",
#       "holiday_date": "2021-12-24",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Christmas Day",
#       "holiday_date": "2021-12-25",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "New Year's Eve",
#       "holiday_date": "2021-12-31",
#       "type_observance": "Observance"
#     }
#   ],
#   "Slovakia": [
#     {
#       "holiday_name": "Republic Day",
#       "holiday_date": "2021-01-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Epiphany",
#       "holiday_date": "2021-01-06",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "March Equinox",
#       "holiday_date": "2021-03-20T10:37:30+01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Struggle for Human Rights Day",
#       "holiday_date": "2021-03-25",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Good Friday",
#       "holiday_date": "2021-04-02",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Easter Sunday",
#       "holiday_date": "2021-04-04",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Easter Monday",
#       "holiday_date": "2021-04-05",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Unfairly Prosecuted Persons Day",
#       "holiday_date": "2021-04-13",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Labor Day",
#       "holiday_date": "2021-05-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Anniversary of the Decease of M. R. \u0160tef\u00e1nik",
#       "holiday_date": "2021-05-04",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "End of World War II",
#       "holiday_date": "2021-05-08",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Anniversary of the Memorandum of the Slovak Nation",
#       "holiday_date": "2021-06-07",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "June Solstice",
#       "holiday_date": "2021-06-21T05:32:08+02:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "St. Cyril & St. Methodius Day",
#       "holiday_date": "2021-07-05",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Foreign Slovaks Day",
#       "holiday_date": "2021-07-05",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Independence Day",
#       "holiday_date": "2021-07-17",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Matice Slovenska Day",
#       "holiday_date": "2021-08-04",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "National Uprising Day",
#       "holiday_date": "2021-08-29",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Constitution Day",
#       "holiday_date": "2021-09-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Day of the Victims of Holocaust and of racial violence",
#       "holiday_date": "2021-09-09",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Day of Our Lady of Sorrows",
#       "holiday_date": "2021-09-15",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Foundation of the Slovak National Council Day",
#       "holiday_date": "2021-09-19",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "September Equinox",
#       "holiday_date": "2021-09-22T21:21:10+02:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Dukla Pass Victims Day",
#       "holiday_date": "2021-10-06",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "\u010cernov\u00e1 Tragedy Day",
#       "holiday_date": "2021-10-27",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Establishment of the Independent Czecho-Slovak State",
#       "holiday_date": "2021-10-28",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Birth of \u013dudov\u00edt \u015ct\u00far Day",
#       "holiday_date": "2021-10-29",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Anniversary of the Declaration of the Slovak Nation",
#       "holiday_date": "2021-10-30",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Reformation Day",
#       "holiday_date": "2021-10-31",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "All Saints' Day",
#       "holiday_date": "2021-11-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Fight for Freedom and Democracy Day",
#       "holiday_date": "2021-11-17",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "December Solstice",
#       "holiday_date": "2021-12-21T16:59:17+01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Christmas Eve",
#       "holiday_date": "2021-12-24",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Christmas Day",
#       "holiday_date": "2021-12-25",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "St. Stephen's Day",
#       "holiday_date": "2021-12-26",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Day of the Declaration of Slovakia as an Independent Ecclesiastic Province",
#       "holiday_date": "2021-12-30",
#       "type_observance": "Observance"
#     }
#   ],
#   "Cabo Verde": [
#     {
#       "holiday_name": "New Year",
#       "holiday_date": "2021-01-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Democracy Day",
#       "holiday_date": "2021-01-13",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "National Heroes' Day",
#       "holiday_date": "2021-01-20",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "March Equinox",
#       "holiday_date": "2021-03-20T08:37:30-01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Labour Day",
#       "holiday_date": "2021-05-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Mother's Day",
#       "holiday_date": "2021-05-09",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "Children's Day",
#       "holiday_date": "2021-06-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Father's Day",
#       "holiday_date": "2021-06-20",
#       "type_observance": "Observance"
#     },
#     {
#       "holiday_name": "June Solstice",
#       "holiday_date": "2021-06-21T02:32:08-01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Independence Day",
#       "holiday_date": "2021-07-05",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "Assumption of Mary",
#       "holiday_date": "2021-08-15",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "September Equinox",
#       "holiday_date": "2021-09-22T18:21:10-01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "All Saints' Day",
#       "holiday_date": "2021-11-01",
#       "type_observance": "National holiday"
#     },
#     {
#       "holiday_name": "December Solstice",
#       "holiday_date": "2021-12-21T14:59:17-01:00",
#       "type_observance": "Season"
#     },
#     {
#       "holiday_name": "Christmas Day",
#       "holiday_date": "2021-12-25",
#       "type_observance": "National holiday"
#     }
#   ]
# }

# %%
#connection with freuenloop database 
conn = psycopg2.connect(host='localhost', port = 5432, database='frauenloop', user=os.environ.get('USERNAME_POSTGRES'), password=os.environ.get('USERNAME_PASSWORD'))
cur = conn.cursor()
conn.commit()

with open('selected_holiday_info.json','r') as country_holiday_file:
    holiday_responses = json.load(country_holiday_file)
hol_info,country_list = prepare_holiday_info_for_df(holiday_responses)
#insert_holiday_info_to_table(""" INSERT INTO holiday (country_name,holiday_name,holiday_date,type_observance) VALUES (%s,%s,%s,%s)""",hol_info)
#insert_holiday_info_to_table(""" INSERT INTO country (country_name) VALUES (%s)""",country_list)

#create_pandas_table('SELECT * FROM "country"')

# %%
country_list
# Out:
# [('Tunisia',),
#  ('Belgium',),
#  ('Guinea-Bissau',),
#  ('Iraq',),
#  ('El Salvador',),
#  ('Namibia',),
#  ('Kuwait',),
#  ('East Timor',),
#  ('Nauru',),
#  ('eSwatini',),
#  ('Panama',),
#  ('Lebanon',),
#  ('Serbia',),
#  ('Greenland',),
#  ('Grenada',),
#  ('South Africa',),
#  ('New Caledonia',),
#  ('Bangladesh',),
#  ('Bulgaria',),
#  ('Gambia',),
#  ('Kazakhstan',),
#  ('Albania',),
#  ('Monaco',),
#  ('Honduras',),
#  ('Eritrea',),
#  ('Reunion',),
#  ('South Sudan',),
#  ('Argentina',),
#  ('Peru',),
#  ('Cayman Islands',),
#  ('Philippines',),
#  ('Maldives',),
#  ('Wallis and Futuna',),
#  ('Czechia',),
#  ('Venezuela',),
#  ('North Macedonia',),
#  ('Chile',),
#  ('Turkey',),
#  ('Costa Rica',),
#  ('Colombia',),
#  ('Laos',),
#  ('Lithuania',),
#  ('United States',),
#  ('Cyprus',),
#  ('Ecuador',),
#  ('Somalia',),
#  ('United Kingdom',),
#  ('Spain',),
#  ('Syria',),
#  ('Burkina Faso',),
#  ('Samoa',),
#  ('Hungary',),
#  ('Gabon',),
#  ('Kiribati',),
#  ('Greece',),
#  ('British Virgin Islands',),
#  ('Cuba',),
#  ('Cameroon',),
#  ('Denmark',),
#  ('Saint Vincent and the Grenadines',),
#  ('Indonesia',),
#  ('Malaysia',),
#  ('Kyrgyzstan',),
#  ('Saint Kitts and Nevis',),
#  ('Sierra Leone',),
#  ('Guinea',),
#  ('Malta',),
#  ('Micronesia',),
#  ('Suriname',),
#  ('American Samoa',),
#  ('French Polynesia',),
#  ('Jersey',),
#  ('Turks and Caicos Islands',),
#  ('Austria',),
#  ('Iceland',),
#  ('Mozambique',),
#  ('Yemen',),
#  ('Norway',),
#  ('Ukraine',),
#  ('Mexico',),
#  ('Antigua and Barbuda',),
#  ('Faroe Islands',),
#  ('Nepal',),
#  ('Latvia',),
#  ('Zambia',),
#  ('Sint Maarten',),
#  ('Uruguay',),
#  ('Guatemala',),
#  ('Saint Martin',),
#  ('Sao Tome and Principe',),
#  ('Zimbabwe',),
#  ('Hong Kong',),
#  ('Bolivia',),
#  ('Egypt',),
#  ('Georgia',),
#  ('Saint Pierre and Miquelon',),
#  ('St. Barts',),
#  ('Anguilla',),
#  ('Russia',),
#  ('Jamaica',),
#  ('Thailand',),
#  ('India',),
#  ('Ireland',),
#  ('Martinique',),
#  ('Saudi Arabia',),
#  ('Cambodia',),
#  ('Sudan',),
#  ('China',),
#  ('Lesotho',),
#  ('Central African Republic',),
#  ('Papua New Guinea',),
#  ('Isle of Man',),
#  ('New Zealand',),
#  ('Qatar',),
#  ('Belarus',),
#  ('Gibraltar',),
#  ('Uzbekistan',),
#  ('Japan',),
#  ('Belize',),
#  ('Cook Islands',),
#  ('Mauritania',),
#  ('Brazil',),
#  ('Vatican City (Holy See)',),
#  ('Afghanistan',),
#  ('Ghana',),
#  ('Libya',),
#  ('Mayotte',),
#  ('Pakistan',),
#  ('Romania',),
#  ('Uganda',),
#  ('Puerto Rico',),
#  ('Turkmenistan',),
#  ('Bosnia and Herzegovina',),
#  ('Marshall Islands',),
#  ('North Korea',),
#  ('Trinidad and Tobago',),
#  ('Angola',),
#  ('Barbados',),
#  ('Macau',),
#  ('Madagascar',),
#  ('Benin',),
#  ('Comoros',),
#  ('Nicaragua',),
#  ('Singapore',),
#  ('Slovenia',),
#  ('Oman',),
#  ('Tanzania',),
#  ('Kenya',),
#  ('US Virgin Islands',),
#  ('Malawi',),
#  ('Finland',),
#  ('Andorra',),
#  ('Armenia',),
#  ('Montenegro',),
#  ('Bhutan',),
#  ('Djibouti',),
#  ('Sweden',),
#  ('Luxembourg',),
#  ('San Marino',),
#  ('Palau',),
#  ('Ethiopia',),
#  ('Fiji',),
#  ('Guyana',),
#  ('Mongolia',),
#  ('Vanuatu',),
#  ('Germany',),
#  ('Northern Mariana Islands',),
#  ('Chad',),
#  ('Botswana',),
#  ('Falkland Islands',),
#  ('Guernsey',),
#  ('Brunei',),
#  ('Poland',),
#  ('Dominica',),
#  ('Paraguay',),
#  ('Seychelles',),
#  ('Italy',),
#  ('Niger',),
#  ('South Korea',),
#  ('Guam',),
#  ('Bahrain',),
#  ('Mali',),
#  ('Togo',),
#  ('Kosovo',),
#  ('Canada',),
#  ('Netherlands',),
#  ('Congo',),
#  ('Moldova',),
#  ('Switzerland',),
#  ('United Arab Emirates',),
#  ('Estonia',),
#  ('Senegal',),
#  ('Saint Helena',),
#  ('Solomon Islands',),
#  ('Taiwan',),
#  ('Congo Democratic Republic',),
#  ('Haiti',),
#  ('Tajikistan',),
#  ('Portugal',),
#  ('Jordan',),
#  ('Australia',),
#  ('Rwanda',),
#  ('Morocco',),
#  ('The Bahamas',),
#  ('Algeria',),
#  ('Croatia',),
#  ('Tuvalu',),
#  ('Vietnam',),
#  ('Mauritius',),
#  ('Curaçao',),
#  ('Burundi',),
#  ('Azerbaijan',),
#  ('Israel',),
#  ('Nigeria',),
#  ('France',),
#  ('Saint Lucia',),
#  ('Liechtenstein',),
#  ('Sri Lanka',),
#  ('Bermuda',),
#  ('Dominican Republic',),
#  ('Aruba',),
#  ('Montserrat',),
#  ('Myanmar',),
#  ('Liberia',),
#  ('Tonga',),
#  ('Iran',),
#  ("Cote d'Ivoire",),
#  ('Equatorial Guinea',),
#  ('Slovakia',),
#  ('Cabo Verde',)]
